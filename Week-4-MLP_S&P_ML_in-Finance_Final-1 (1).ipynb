# %% [markdown]
# <html> <h1 style="font-style:bold; color:blue;"> Machine Learning in Finance </h1> </html>

# %% [markdown]
# <html> <h1 style="font-style:italic; color:blue;"> Week-4 </h1> </html>

# %% [markdown]
# ### Your first price forecast model

# %% [markdown]
# ## S&P-500 Index Prices Forecast using a Multilayer Perceptron (MLP) Neural network

# %% [markdown]
# #### It is a training example of forecasting the S&P 500 Index at the prices of the previous minute of all shares included in this Index. The value of the Index is predicted for the next minute following the current minute.
# #### A multilayer perceptron (MLP) Neural network with fully connected layers (dense) is used.
# #### The dataset consists of the Index (outputs) and stock prices (inputs) for five months of 2017 of the S&P 500 constituents.

# %% [markdown]
# #### The S&P-500 (S&P) is a stock market index that measures the stock performance of 500 large companies listed on stock exchanges in the United States. The weight of each company in the index is proportional to its capitalization (more precisely, free-float)

# %% [markdown]
# #### "S&P-500 Index": (https://en.wikipedia.org/wiki/S%26P_500_Index)

# %% [markdown]
# #### ! Note that this notebook is a hands-on tutorial on machine learning in Finance. Live forecasting of stock prices is a challenging and complex task that requires tremendous effort, especially at higher frequencies, such as the one-minute timeframe used here.

# %% [markdown]
# ##### **Source** - paper "A simple deep learning model for stock price prediction using TensorFlow":
# (https://medium.com/mlreview/a-simple-deep-learning-model-for-stock-price-prediction-using-tensorflow-30505541d877).

# %% [markdown]
# .........................................................![image.png](attachment:d579437e-4c98-4640-89b5-bbf0ace4e99e.png)

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# .........................................................![image.png](attachment:6dfa05e1-62da-475a-9373-d120da1dabd2.png)

# %%
np.random.seed(42)

# %% [markdown]
# <html> <h3 style="color:blue;"> Dataset </h3> </html>

# %% [markdown]
# .........................................................![image.png](attachment:33f6935b-9b68-4b3a-8c28-61aced6a00ce.png)

# %%
data = pd.read_csv('data_stocks.csv')
data.head()
# Out:
#          DATE      SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# 0  1491226200  2363.6101     42.3300     143.6800     129.6300      82.040
# 1  1491226260  2364.1001     42.3600     143.7000     130.3200      82.080
# 2  1491226320  2362.6799     42.3100     143.6901     130.2250      82.030
# 3  1491226380  2364.3101     42.3700     143.6400     130.0729      82.000
# 4  1491226440  2364.8501     42.5378     143.6600     129.8800      82.035
#
#    NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  ...  NYSE.WYN  NYSE.XEC  \
# 0    102.2300      85.2200       59.760       121.52  ...    84.370   119.035
# 1    102.1400      85.6500       59.840       121.48  ...    84.370   119.035
# 2    102.2125      85.5100       59.795       121.93  ...    84.585   119.260
# 3    102.1400      85.4872       59.620       121.44  ...    84.460   119.260
# 4    102.0600      85.7001       59.620       121.60  ...    84.470   119.610
#
#    NYSE.XEL  NYSE.XL  NYSE.XOM  NYSE.XRX  NYSE.XYL  NYSE.YUM  NYSE.ZBH  \
# 0     44.40    39.88     82.03      7.36     50.22     63.86   122.000
# 1     44.11    39.88     82.03      7.38     50.22     63.74   121.770
# 2     44.09    39.98     82.02      7.36     50.12     63.75   121.700
# 3     44.25    39.99     82.02      7.35     50.16     63.88   121.700
# 4     44.11    39.96     82.03      7.36     50.20     63.91   121.695
#
#    NYSE.ZTS
# 0    53.350
# 1    53.350
# 2    53.365
# 3    53.380
# 4    53.240
#
# [5 rows x 502 columns]

# %% [markdown]
# .........................................................![image.png](attachment:f9ca54a1-19a8-4c70-b638-8234806a1dc1.png)

# %%
data.tail(3)
# Out:
#              DATE    SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# 41263  1504209480  2470.03       44.74       164.01      155.065       83.62
# 41264  1504209540  2471.49       44.71       163.88      154.960       83.58
# 41265  1504209600  2471.49       44.74       163.98      155.160       83.69
#
#        NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  ...  NYSE.WYN  \
# 41263      106.52       114.47       47.150       142.33  ...    99.735
# 41264      106.40       114.33       47.135       142.17  ...    99.700
# 41265      106.47       114.46       47.150       142.41  ...    99.670
#
#        NYSE.XEC  NYSE.XEL  NYSE.XL  NYSE.XOM  NYSE.XRX  NYSE.XYL  NYSE.YUM  \
# 41263     99.64    49.495   40.940    76.315    32.290    62.090     76.88
# 41264     99.63    49.485   40.925    76.300    32.275    62.075     76.83
# 41265     99.64    49.490   40.940    76.320    32.270    62.070     76.81
#
#        NYSE.ZBH  NYSE.ZTS
# 41263    114.31   62.6850
# 41264    114.23   62.6301
# 41265    114.28   62.6800
#
# [3 rows x 502 columns]

# %% [markdown]
# .........................................................![image.png](attachment:19d86cf9-39cc-4860-8ec2-a09a860fc129.png)

# %%
print(data.shape)
data.info()
# Out:
# (41266, 502)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41266 entries, 0 to 41265
# Columns: 502 entries, DATE to NYSE.ZTS
# dtypes: float64(501), int64(1)
# memory usage: 158.0 MB

# %%
# We have 501 float64 and one int64 variables. All data are numerical!

# %% [markdown]
# .........................................................![image.png](attachment:efc952ed-49e8-4898-b733-0cd6b4c5efc3.png)

# %%
data.dtypes
# Out:
# DATE             int64
# SP500          float64
# NASDAQ.AAL     float64
# NASDAQ.AAPL    float64
# NASDAQ.ADBE    float64
#                 ...
# NYSE.XRX       float64
# NYSE.XYL       float64
# NYSE.YUM       float64
# NYSE.ZBH       float64
# NYSE.ZTS       float64
# Length: 502, dtype: object

# %%
# So we actually have 500 shares prices and an Index price for each minute

# %% [markdown]
# .........................................................![image.png](attachment:18e16300-3a0f-436d-8d3c-48638737c299.png)

# %%
plt.figure(num=1, figsize=(15,7))
plt.hist(data['NYSE.XEL'], bins=100)
plt.title('NYSE.XEL price distribution', size=18)
plt.ylabel('Numbers',size=14)
plt.xlabel('Price', size=14)
# Out:
# Text(0.5, 0, 'Price')

# %%
# Guess visually where the support and resistance levels were

# %% [markdown]
# .........................................................![image.png](attachment:ec73b313-3e44-4e56-96f9-64b56e054365.png)

# %%
plt.figure(num=1, figsize=(15,7))
plt.plot(data['SP500']);

# %% [markdown]
# .........................................................![image.png](attachment:ad3190a3-a9c4-476e-9c39-8f0a33ce57b1.png)

# %%
data = data.drop(['DATE'], axis=1)

# %% [markdown]
# .........................................................![image.png](attachment:ff7de325-f0ec-46fa-8733-05707b97c0a9.png)

# %%
data.shape
# Out:
# (41266, 501)

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;">
# The aim is to forecast the S&P-500 index prices soon (in our example, the S&P-500 price in the next minute). It requires some data preprocessing.
#
# You have to shift the S&P-500 forward one minute so that each row contains the prices of 500 shares in the current minute and the S&P-500 index price in the next minute.
# </h3> </html>

# %% [markdown]
# .........................................................![image.png](attachment:da1020e8-40ad-49d5-a978-e75343c7490e.png)

# %%
data['SP500']
# Out:
# 0        2363.6101
# 1        2364.1001
# 2        2362.6799
# 3        2364.3101
# 4        2364.8501
#            ...
# 41261    2472.2200
# 41262    2471.7700
# 41263    2470.0300
# 41264    2471.4900
# 41265    2471.4900
# Name: SP500, Length: 41266, dtype: float64

# %% [markdown]
# .........................................................![image.png](attachment:417cb6c7-19cd-484e-ab13-c03ff2206d28.png)

# %%
data['SP500'] = data['SP500'].shift(-1)
data['SP500']
# Out:
# 0        2364.1001
# 1        2362.6799
# 2        2364.3101
# 3        2364.8501
# 4        2365.6201
#            ...
# 41261    2471.7700
# 41262    2470.0300
# 41263    2471.4900
# 41264    2471.4900
# 41265          NaN
# Name: SP500, Length: 41266, dtype: float64

# %%
# You can see that the S&P prices column was shifted up

# %% [markdown]
# .........................................................![image.png](attachment:524e07fa-b517-4139-aed9-3f6f5034dfed.png)

# %%
data = data.dropna(axis=0)
data['SP500']
# Out:
# 0        2364.1001
# 1        2362.6799
# 2        2364.3101
# 3        2364.8501
# 4        2365.6201
#            ...
# 41260    2472.2200
# 41261    2471.7700
# 41262    2470.0300
# 41263    2471.4900
# 41264    2471.4900
# Name: SP500, Length: 41265, dtype: float64

# %% [markdown]
# .........................................................![image.png](attachment:b32bc6bd-8550-48e5-aa64-2828cb8687f1.png)

# %%
data.shape
# Out:
# (41265, 501)

# %%
# Now we have one row less

# %% [markdown]
# .........................................................![image.png](attachment:e8dea7b1-c065-4a07-b0b3-eff78d47db8e.png)

# %%
data_a = np.array(data)

print("data_a:")
print(data_a[:5,:],'\n')
print(data_a[-5:,:])
print("type:", data_a.dtype)
# Out:
# data_a:
# [[2364.1001   42.33    143.68   ...   63.86    122.       53.35  ]
#  [2362.6799   42.36    143.7    ...   63.74    121.77     53.35  ]
#  [2364.3101   42.31    143.6901 ...   63.75    121.7      53.365 ]
#  [2364.8501   42.37    143.64   ...   63.88    121.7      53.38  ]
#  [2365.6201   42.5378  143.66   ...   63.91    121.695    53.24  ]]
#
# [[2472.22     44.71    164.14   ...   76.885   114.3      62.73  ]
#  [2471.77     44.72    164.11   ...   76.88    114.31     62.725 ]
#  [2470.03     44.73    164.12   ...   76.9     114.33     62.71  ]
#  [2471.49     44.74    164.01   ...   76.88    114.31     62.685 ]
#  [2471.49     44.71    163.88   ...   76.83    114.23     62.6301]]
# type: float64

# %% [markdown]
# .........................................................![image.png](attachment:ed172b0d-bac6-45ea-a33a-b68014f00608.png)

# %%
data = []
data
# Out:
# []

# %% [markdown]
# <html> <h3 style="color:blue;"> Data for training and testing </h3> </html>

# %% [markdown]
# .........................................................![image.png](attachment:b1fb582e-7b59-45f7-904b-2f63f42fce26.png)

# %%
n = data_a.shape[0]
train_start = 0
train_end = int(np.floor(0.8*n))
print(train_end)
# Out:
# 33012

# %% [markdown]
# .........................................................![image.png](attachment:e92704ea-cb4a-4b30-9411-11a9535c65bf.png)

# %%
train_end -= 12
print(train_end)
# Out:
# 33000

# %% [markdown]
# .........................................................![image.png](attachment:65cd57f0-b4c6-49e0-91bd-828e0f1e34bd.png)

# %%
test_start = train_end
test_end = n

data_train = data_a[np.arange(train_start, train_end),:]
data_test = data_a[np.arange(test_start, test_end),:]

# %% [markdown]
# .........................................................![image.png](attachment:f822633d-115a-49cc-957a-cb782ce04440.png)

# %%
print('Data for training:', data_train.shape)
print('Data for testing:', data_test.shape)
# Out:
# Data for training: (33000, 501)
# Data for testing: (8265, 501)

# %% [markdown]
# .........................................................![image.png](attachment:8ef74910-a136-46dd-a90a-47d01ca91453.png)

# %%
data_a=[]
data_a
# Out:
# []

# %% [markdown]
# <html> <h3 style="color:blue;"> Data normalisation </h3> </html>

# %% [markdown]
# ![image.png](attachment:da48fee3-b725-4785-816b-f531b7c65328.png)

# %% [markdown]
# .........................................................![image.png](attachment:70f276d6-f087-420a-bf84-2c0ce58b3f51.png)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %% [markdown]
# <html> <h3 style="color:red;"> !!! Note: </h3> </html>
#
# <html> <h3 style="font-style:italic; color:blue;">
#
# A typical mistake when choosing a part of the data and time for scaling is to scale the entire dataset before dividing it into test and training data. It is a mistake because scaling starts the calculation of statistics, that is, minima/maxima of variables. When realising time series forecasting in real life, at the time of their generation, you cannot have information from observations in the future.
#
# Therefore, statistics should be calculated on the training data, and then the result should be applied to the test data. Otherwise, by taking information “from the future” to generate predictions (that is, from a test sample), the model will produce forecasts with “system bias.”
#
# </h3> </html>

# %% [markdown]
# .........................................................![image.png](attachment:0854ac19-9b7a-43c5-90bd-c8eebdb64e12.png)

# %%
scaler.fit(data_train)

data_train_norm = scaler.transform(data_train)
data_test_norm = scaler.transform(data_test)

# %% [markdown]
# .........................................................![image.png](attachment:a802084b-2fa3-442d-9458-3e76dbe41412.png)

# %%
print(data_train_norm.min())
print(data_train_norm.max(), '\n')

print(data_test_norm.min())
print(data_test_norm.max())
# Out:
# 0.0
# 1.0000000000000018
#
# -1.7208737864077674
# 2.115201718054915

# %% [markdown]
# The first two numbers above mean that all columns (stock prices and S&P index price) are normalised in the range [0,1].
# In this case, the normalisation occurs for each column separately.
#
# The following two numbers mean that there are stocks (not necessarily all of them) whose prices changed during the last 20% period (test dataset) in broader ranges than they changed during the first 80% period (training dataset).
#
# It is acceptable that after normalisation, some stocks go beyond the range [0,1] since they still are in the same order with this range.

# %% [markdown]
# <html> <h3 style="color:blue;"> A matrix of input parameters and an output vector for training and test datasets </h3> </html>

# %%
# create two data sets: 
# for training: (X_train, y_train)
# and for tests: (X_test, y_test)

# X_train and X_test are matrixes with 1-minute time-frame prices of 500 stocks
# y_train and y_test are S&P-500 values in the next minute

# %% [markdown]
# .........................................................![image.png](attachment:image.png)

# %%
X_train = data_train_norm[:, 1:]
y_train = data_train_norm[:, 0:]
X_test = data_test_norm[:, 1:]
y_test = data_test_norm[:, 0:]

# %% [markdown]
# .........................................................![image.png](attachment:21772b3c-cdf1-414c-936a-8775e186df88.png)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (33000, 500)
# (33000, 501)
# (8265, 500)
# (8265, 501)

# %% [markdown]
# <html> <h2 style="color:blue;"> Neural Network (Multilayer Perceptron - MLP) </h2> </html>

# %% [markdown]
# #### Now just press 'CTRL' and 'ENTER' keys on the next cells.

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\preyp\anaconda3\lib\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\preyp\anaconda3\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\preyp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\preyp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\preyp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\preyp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\preyp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\preyp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\preyp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\preyp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\preyp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\preyp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.2)
# Requirement already satisfied: setuptools in c:\users\preyp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\preyp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\preyp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\preyp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\preyp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\preyp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.68.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\preyp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\preyp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.6.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\preyp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\preyp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\preyp\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\preyp\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\preyp\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.3.5)
# Requirement already satisfied: namex in c:\users\preyp\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\preyp\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\preyp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\preyp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\preyp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\preyp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\preyp\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\preyp\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\preyp\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\preyp\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\preyp\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\preyp\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\preyp\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import TensorFlow and Keras

import tensorflow as tf
from tensorflow import keras

# %%
# If you have a problem with TensorFlow import as shown above,
# you have to install TensorFlow:
# Otherwise, please ignore the next two cells

# %%
#pip install --upgrade pip

# %%
#pip install tensorflow

# %% [markdown]
# <html> <h3 style="color:red;"> !! restart the kernel </h3> </html>

# %% [markdown]
# ![image.png](attachment:b04a62f9-085a-48d9-a343-e3db3d973895.png)

# %%
# Run import TensoFlow after installing

# %%
# import TensorFlow and Keras

import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# .........................................................![image.png](attachment:f5b7278f-8f96-4088-bfc6-637544188dca.png)

# %%
print(tf.__version__)
# Out:
# 2.18.0

# %% [markdown]
# <html> <h4 style="color:blue;">
#
# The Multilayer Perceptron architecture:
#
# Number of input neurons = Number of stocks for training = 500
# - Model (Neural network) consists of 4 hidden levels:
#  - The first contains 1024 neurons, which is slightly more than twice the amount of input data
#  - The subsequent hidden levels are half the previous level: 512, 256 and 128 neurons
#  - Reducing the number of neurons at each level compresses the information that the network processed at previous levels
#  - output layer - ONE neuron (predicted S&P price) as this is a regression task
#
# </h4> </html>

# %% [markdown]
# .........................................................![image.png](attachment:image.png)

# %%
model = keras.Sequential([
    keras.layers.Dense(1024, input_dim=500, activation=tf.nn.relu, kernel_initializer="normal"),

    keras.layers.Dense(512, activation='relu', kernel_initializer="normal"),

    keras.layers.Dense(256, activation='relu', kernel_initializer="normal"),

    keras.layers.Dense(128, activation='relu', kernel_initializer="normal"),

    keras.layers.Dense(1)
])
print(model.summary())
# Out:
# C:\Users\preyp\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 1024)                │         513,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,202,177 (4.59 MB)
#  Trainable params: 1,202,177 (4.59 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# .........................................................![image.png](attachment:11f3c506-2886-4aef-bae0-575428f41234.png)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mae"])

# %% [markdown]
# <html> <h3 style="color:blue;"> Training the Neural Network </h3> </html>

# %% [markdown]
# ![image.png](attachment:0624706f-5ef9-4a1c-9eaf-4d1a55a4377a.png)

# %% [markdown]
# #### <font color='red'>!!! If neural network training is slow and you spend more than one minute on one epoch, restart the Kernel, reduce the number of epochs to 10, and run again.</font>

# %% [markdown]
# .................![image.png](attachment:21332a6e-e620-42d2-b956-1adf03b3d734.png)

# %%
history = model.fit(X_train, y_train, batch_size=10, epochs=10, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/10
# 2640/2640 ━━━━━━━━━━━━━━━━━━━━ 43s 15ms/step - loss: 0.0615 - mae: 0.2040 - val_loss: 0.0707 - val_mae: 0.2290
# Epoch 2/10
# 2640/2640 ━━━━━━━━━━━━━━━━━━━━ 36s 14ms/step - loss: 0.0571 - mae: 0.2001 - val_loss: 0.0707 - val_mae: 0.2297
# Epoch 3/10
# 2640/2640 ━━━━━━━━━━━━━━━━━━━━ 40s 15ms/step - loss: 0.0564 - mae: 0.1992 - val_loss: 0.0707 - val_mae: 0.2296
# Epoch 4/10
# 2640/2640 ━━━━━━━━━━━━━━━━━━━━ 37s 14ms/step - loss: 0.0564 - mae: 0.1993 - val_loss: 0.0706 - val_mae: 0.2292
# Epoch 5/10
# 2640/2640 ━━━━━━━━━━━━━━━━━━━━ 38s 14ms/step - loss: 0.0564 - mae: 0.1993 - val_loss: 0.0706 - val_mae: 0.2291
# Epoch 6/10
# 2640/2640 ━━━━━━━━━━━━━━━━━━━━ 39s 15ms/step - loss: 0.0562 - mae: 0.1988 - val_loss: 0.0708 - val_mae: 0.2279
# Epoch 7/10
# 2640/2640 ━━━━━━━━━━━━━━━━━━━━ 36s 14ms/step - loss: 0.0562 - mae: 0.1989 - val_loss: 0.0707 - val_mae: 0.2294
# Epoch 8/10
# 2640/2640 ━━━━━━━━━━━━━━━━━━━━ 34s 13ms/step - loss: 0.0564 - mae: 0.1992 - val_loss: 0.0708 - val_mae: 0.2279
# Epoch 9/10
# 2640/2640 ━━━━━━━━━━━━━━━━━━━━ 35s 13ms/step - loss: 0.0562 - mae: 0.1988 - val_loss: 0.0707 - val_mae: 0.2282
# Epoch 10/10
# 2640/2640 ━━━━━━━━━━━━━━━━━━━━ 38s 14ms/step - loss: 0.0563 - mae: 0.1990 - val_loss: 0.0708 - val_mae: 0.2277

# %% [markdown]
# <html> <h3 style="color:blue;"> Evaluation </h3> </html>

# %% [markdown]
# ................................................![image.png](attachment:ba00113a-5d6b-4834-9fdf-52f99e40d12b.png)

# %%
mse, mae = model.evaluate(X_test, y_test, verbose=0)
print("Mean absolute error:%.5f"% mae)
print("Mean squared error:%.5f"% mse)
# Out:
# Mean absolute error:0.33341
# Mean squared error:0.17167

# %% [markdown]
# <html> <h3 style="color:blue;"> Training process graph </h3> </html>

# %% [markdown]
# #### Mean Absolute Error (MAE) Chart

# %% [markdown]
# ##### Now just press 'CTRL' and 'ENTER' keys on the next cells.

# %%
history_dict = history.history

mean_absolute_error_values = history_dict['mae']
val_mean_absolute_error_values = history_dict['val_mae']
epochs = range(1, len(mean_absolute_error_values) + 1)

plt.figure(num=1, figsize=(15,7))
plt.plot(epochs, mean_absolute_error_values, 'bo', label='Training mae')
plt.plot(epochs, val_mean_absolute_error_values, 'b', label='Validation mae')
plt.xlabel('Epochs')
plt.ylabel('Mean Absolute Error - mae')
plt.legend()
plt.show()

# %% [markdown]
# ##### Type the code below by copying and slightly changing the previous cell code

# %% [markdown]
# ...................................![image.png](attachment:7e2e3e88-3c3f-40cd-905a-c831d2f67777.png)

# %%
histroy_dict = history.history

mean_absolute_error_values = history_dict['loss']
val_mean_absolute_error_values = history_dict['val_loss']
epochs = range(1, len(mean_absolute_error_values) + 1)

plt.figure(num=1, figsize=(15,7))
plt.plot(epochs, mean_absolute_error_values, 'bo', label='Training mse')
plt.plot(epochs, val_mean_absolute_error_values, 'b', label='Validation mse')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error - mse')
plt.legend()
plt.show()

# %% [markdown]
# <html> <h3 style="color:blue;"> Using the neural network to predict the price of the S&P-500 </h3> </html>

# %%
# Based on the MinMaxScaler formula, let's calculate the parameters for restoring absolute prices from normalised ones.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ...................................![image.png](attachment:56332b8c-142f-4b48-ad7e-6931c35b8eaa.png)

# %%
sp500_min_train_min = data_train[:,0].min()
sp500_min_train_max = data_train[:,0].max()

print(sp500_min_train_min, '\n', sp500_min_train_max)
# Out:
# 2329.1399
#  2482.8701

# %% [markdown]
# ........................................![image.png](attachment:b7cdf473-7fb0-4812-bad1-b54c1845a42b.png)

# %%
sp500_min_train_delta = data_train[:,0].max() - data_train[:,0].min()
sp500_min_train_delta
# Out:
# 153.73019999999997

# %% [markdown]
# #### Now just press 'CTRL' and 'ENTER' keys on the next cells.

# %%
import random

pred = model.predict(X_test)

n_rec = random.randint(0, X_test.shape[0])

predicted_price = pred[n_rec][0] * sp500_min_train_delta + sp500_min_train_min
actual_price    = y_test[n_rec]  * sp500_min_train_delta + sp500_min_train_min

print(" Predicted price:", predicted_price, '\n' , 
      "Actual price:", actual_price, '\n', 
      "absolut error:", predicted_price - actual_price, '\n',
      "% absolut error:", (predicted_price - actual_price) / actual_price * 100,"%")
# Out:
# 259/259 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#  Predicted price: 2408.8840894121768
#  Actual price: [2440.3999     2376.57149707 2495.68754334 2490.37252277 2372.5853913
#  2382.0848183  2460.93606897 2326.356234   2481.53032842 2418.97644889
#  2390.82883127 2427.46222151 2378.33514247 2476.20429187 2438.97858442
#  2344.64617707 2475.26765368 2381.151951   2523.82447087 2440.91877565
#  2424.31286927 2399.6841136  2461.96339193 2466.49449174 2425.74467549
#  2470.926446   2338.46109765 2362.26966715 2379.98272515 2435.76172549
#  2475.15391236 2300.55992153 2298.34029547 2301.5681152  2312.93244355
#  2458.27679392 2473.96324942 2408.35097253 2501.75571228 2380.79456324
#  2461.69211965 2393.12009884 2408.32453553 2333.60214315 2447.67275506
#  2340.90438918 2412.01679553 2461.43854397 2433.70133158 2342.83586327
#  2350.35753133 2473.90242421 2416.74019835 2414.09079783 2433.11741709
#  2316.30787504 2329.78703368 2370.31763214 2185.32777742 2362.81695392
#  2327.49938208 2477.54696387 2373.20735711 2429.30799412 2379.71858608
#  2450.36608121 2489.96855907 2544.63917135 2322.53636907 2332.11791958
#  2470.99298542 2448.65439515 2407.3574651  2262.30068261 2444.10252154
#  2270.19850045 2496.39338352 2455.86073313 2431.4702316  2119.62653277
#  2332.85213494 2486.8717538  2414.57394511 2343.44038372 2373.74527577
#  2470.73426726 2404.33401957 2407.68327729 2375.17413596 2331.84747691
#  2358.31815326 2373.1694233  2357.82919217 2292.83626676 2475.19583617
#  2337.49669456 2401.39004508 2431.25682987 2401.19916065 2339.55134851
#  2471.60854655 2517.46804449 2485.70192242 2301.97331165 2323.43771125
#  2377.71829559 2391.04661635 2393.85924508 2470.5129226  2395.97911739
#  2413.42645793 2252.42527276 2293.89176129 2364.1267731  2467.66601429
#  2447.1115053  2409.23241208 2426.34422213 2463.44531799 2467.38779313
#  2442.81785811 2443.90022958 2157.50537952 2444.63464    2506.07465849
#  2316.88675929 2456.91860678 2322.02645043 2465.50493406 2475.71034351
#  2365.71177563 2286.56037641 2615.17887869 2500.08594259 2390.63198
#  2476.69655276 2477.44632227 2346.84842093 2363.60760646 2456.85422
#  2357.81574151 2443.75531538 2433.98099837 2252.08413493 2446.87127348
#  2398.4388604  2447.01713492 2429.99409466 2430.74069908 2529.92447909
#  2389.094678   2477.75073026 2466.67399948 2241.70642697 2317.47143779
#  2441.64969663 2508.61439187 2429.50829857 2405.77991918 2381.20272616
#  2461.82753228 2463.46725922 2467.81257108 2384.24172018 2351.17599885
#  2461.92673268 2405.51286042 2463.4850413  2440.48125809 2482.76284562
#  2475.12223584 2445.65863004 2373.68057679 2376.18919171 2329.1399
#  2441.33228836 2419.52703426 2328.6155041  2500.42477614 2486.22982676
#  2425.79115267 2427.50366782 2350.6688558  2455.29632113 2321.82393869
#  2290.1290096  2483.12814482 2400.28219693 2399.31104234 2391.25372607
#  2512.80703368 2487.87061766 2426.7776854  2335.47928969 2357.98935543
#  2276.78378617 2509.55404492 2341.58988099 2431.09425335 2393.00575515
#  2306.08560637 2381.30334194 2485.60134721 2472.57158849 2526.94412523
#  2384.25313353 2437.78256299 2379.44214524 2598.14629129 2460.57202807
#  2334.76301333 2297.44376846 2325.33065611 2500.11360152 2417.64347604
#  2276.64175507 2328.53227075 2413.87026605 2298.64901918 2439.44630974
#  2369.21067329 2430.38732474 2387.32286651 2347.82613282 2466.37339114
#  2426.91095061 2423.8083136  2367.20642571 2325.33697901 2488.33845882
#  2439.87855667 2471.35342213 2425.69692537 2353.40557688 2367.31283921
#  2489.50810667 2470.14243734 2319.89021838 2347.09609139 2557.72548069
#  2421.02291655 2465.81050656 2412.04459076 2430.11486056 2536.82034627
#  2463.37693343 2375.02000114 2292.75248224 2446.78620583 2421.29308619
#  2474.38006923 2466.77532385 2299.95165936 2452.65877374 2310.87634958
#  2439.09756754 2463.23303066 2405.93568972 2341.51783162 2365.69187726
#  2494.02356384 2435.53978208 2494.4790167  2469.43951935 2285.84965299
#  2266.13223794 2296.71243594 2485.67303492 2375.49882272 2313.56979
#  2440.82036882 2427.73446992 2301.7936625  2308.6107118  2351.5382732
#  2395.78287098 2440.35621726 2347.43886859 2465.22107444 2392.26265107
#  2392.67899534 2319.73486223 2288.81225385 2481.1887408  2337.79682316
#  2370.12920887 2315.60863545 2398.13101415 2301.91352281 2449.87932699
#  2342.39093323 2464.13629118 2292.3242534  2402.65772945 2457.61219696
#  2445.43410992 2276.61139906 2555.5008014  2340.90871914 2329.99221146
#  2525.70187409 2325.17996845 2446.32316469 2423.86254848 2394.69402395
#  2304.27177941 2366.07074399 2540.88768081 2402.15818313 2375.79457092
#  2385.20620824 2332.57373608 2369.44369775 2430.28825299 2330.24102455
#  2442.90103857 2403.94499382 2348.89294246 2362.42793543 2390.33945383
#  2336.3950971  2355.54885894 2437.04432496 2446.25877655 2565.05291132
#  2341.98047355 2421.10114743 2458.02626572 2376.1018671  2246.92740284
#  2275.45965353 2366.13122938 2430.33398052 2468.04663293 2357.68085778
#  2528.95681844 2400.83531186 2518.13789557 2352.7907     2343.65130531
#  2320.44702223 2283.3606857  2461.7266914  2331.62342504 2492.36231249
#  2425.76581267 2304.49345263 2406.90929529 2481.09742633 2392.62858983
#  2464.72612617 2329.06249305 2284.93422017 2453.32711438 2368.341101
#  2292.55640698 2424.07356323 2410.84432457 2435.89280088 2355.81295746
#  2418.58789893 2293.49520337 2405.22683813 2378.51790857 2318.13977085
#  2428.24206328 2420.550242   2364.77007656 2423.11910849 2271.21745882
#  2505.84839361 2511.53166271 2323.74697099 2499.51657537 2381.21482234
#  2383.32254408 2485.70699201 2308.81411645 2471.11409456 2397.68650007
#  2336.78909684 2373.44300244 2403.80885429 2411.81190616 2254.82563296
#  2430.35593993 2354.88771403 2498.76757271 2524.23815617 2413.77028829
#  2426.30388204 2388.31506864 2492.95280947 2477.42987603 2391.69052911
#  2486.60948324 2431.20588126 2486.8353631  2391.95326276 2447.52410194
#  2314.60923726 2491.86674667 2321.32311017 2441.28351094 2488.61997596
#  2334.30835214 2369.96289802 2436.61163092 2512.62433226 2430.9861575
#  2437.62907309 2300.94629848 2417.9959556  2492.21448471 2419.42647495
#  2423.47434091 2343.5441393  2516.0758232  2358.39452761 2404.53087479
#  2507.87844048 2414.39673055 2448.00748059 2328.09952842 2432.30994533
#  2508.80204774 2325.72683358 2379.22546808 2403.09028873 2421.05655688
#  2442.26137482 2246.49676319 2319.15296686 2293.17878145 2318.87518086
#  2371.25856771 2367.64638719 2453.53869693 2495.48551883 2404.723915
#  2457.84984836 2472.587406   2397.69899289 2408.09966505 2406.77486658
#  2397.72722    2379.90706182 2380.08537326 2444.86793468 2400.77525427
#  2413.12213889 2392.75325509 2387.39555474 2419.19826343 2459.20025442
#  2395.11268309 2410.81909812 2481.49639391 2510.22087178 2444.58127681
#  2427.527228   2322.87024656 2302.07668875 2291.0148104  2425.18467257
#  2330.52329888 2493.55977312 2428.67588624 2367.93371041 2482.07762855
#  2377.79694462 2414.00790387 2375.05337727 2511.85347745 2449.53292405
#  2485.23016499 2465.61466939 2316.10501288 2309.86467937 2413.8193817
#  2457.04162179 2446.77412013 2509.30777771 2346.75902178 2342.19856291
#  2477.92784315 2373.4785657  2432.54976691 2405.10639721 2377.1805875
#  2317.71994229 2413.5232925  2371.86758946 2513.82721121 2381.77681644
#  2273.39474336 2478.65671043 2487.01098081 2476.94846843 2309.02253468
#  2451.69777175]
#  absolut error: [ -31.51581059   32.31259234  -86.80345392  -81.48843336   36.29869811
#    26.79927111  -52.05197955   82.52785542  -72.64623901  -10.09235948
#    18.05525814  -18.57813209   30.54894694  -67.32020246  -30.09449501
#    64.23791234  -66.38356427   27.73213841 -114.94038145  -32.03468624
#   -15.42877986    9.19997581  -53.07930252  -57.61040233  -16.86058607
#   -62.04235659   70.42299177   46.61442226   28.90136426  -26.87763608
#   -66.26982294  108.32416789  110.54379394  107.31597422   95.95164586
#   -49.39270451  -65.07916001    0.53311688  -92.87162286   28.08952617
#   -52.80803024   15.76399057    0.55955389   75.28194626  -38.78866565
#    67.97970023   -3.13270612  -52.55445456  -24.81724217   66.04822614
#    58.52655808  -65.0183348    -7.85610894   -5.20670842  -24.23332768
#    92.57621437   79.09705574   38.56645727  223.55631199   46.06713549
#    81.38470733  -68.66287445   35.6767323   -20.42390471   29.16550333
#   -41.48199179  -81.08446966 -135.75508194   86.34772034   76.76616983
#   -62.10889601  -39.77030574    1.52662431  146.5834068   -35.21843213
#   138.68558896  -87.50929411  -46.97664371  -22.58614219  289.25755665
#    76.03195447  -77.98766438   -5.6898557    65.44370569   35.13881364
#   -61.85017785    4.55006985    1.20081212   33.70995345   77.0366125
#    50.56593615   35.71466611   51.05489724  116.04782265  -66.31174675
#    71.38739485    7.49404433  -22.37274046    7.68492876   69.3327409
#   -62.72445714 -108.58395507  -76.81783301  106.91077777   85.44637817
#    31.16579382   17.83747306   15.02484434  -61.62883318   12.90497202
#    -4.54236852  156.45881666  114.99232813   44.75731631  -58.78192487
#   -38.22741589   -0.34832267  -17.46013272  -54.56122858  -58.50370372
#   -33.9337687   -35.01614017  251.37870989  -35.75055059  -97.19056908
#    91.99733012  -48.03451737   86.85763898  -56.62084465  -66.8262541
#    43.17231379  122.323713   -206.29478928  -91.20185317   18.25210941
#   -67.81246335  -68.56223286   62.03566848   45.27648295  -47.97013059
#    51.0683479   -34.87122597  -25.09690896  156.79995448  -37.98718407
#    10.44522901  -38.13304551  -21.11000525  -21.85660967 -121.04038968
#    19.78941141  -68.86664085  -57.78991007  167.17766244   91.41265162
#   -32.76560722  -99.73030245  -20.62420916    3.10417023   27.68136326
#   -52.94344287  -54.58316981  -58.92848167   24.64236923   57.70809056
#   -53.04264327    3.371229    -54.60095189  -31.59716868  -73.8787562
#   -66.23814643  -36.77454062   35.20351262   32.6948977    79.74418941
#   -32.44819895  -10.64294485   80.26858531  -91.54068673  -77.34573735
#   -16.90706326  -18.6195784    58.21523361  -46.41223172   87.06015072
#   118.75507982  -74.24405541    8.60189248    9.57304707   17.63036334
#  -103.92294427  -78.98652825  -17.89359599   73.40479972   50.89473398
#   132.10030324 -100.6699555    67.29420843  -22.21016394   15.87833427
#   102.79848305   27.58074747  -76.7172578   -63.68749908 -118.06003582
#    24.63095589  -28.89847357   29.44194417 -189.26220188  -51.68793866
#    74.12107608  111.44032096   83.55343331  -91.22951211   -8.75938663
#   132.24233435   80.35181866   -4.98617663  110.23507023  -30.56222033
#    39.67341613  -21.50323533   21.5612229    61.05795659  -57.48930172
#   -18.0268612   -14.92422419   41.6776637    83.5471104   -79.45436941
#   -30.99446726  -62.46933272  -16.81283596   55.47851253   41.57125021
#   -80.62401726  -61.25834793   88.99387103   61.78799802 -148.84139128
#   -12.13882714  -56.92641715   -3.16050135  -21.23077115 -127.93625685
#   -54.49284402   33.86408827  116.13160717  -37.90211642  -12.40899678
#   -65.49597982  -57.89123444  108.93243005  -43.77468433   98.00773983
#   -30.21347813  -54.34894124    2.94839969   67.36625779   43.19221216
#   -85.13947443  -26.65569267  -85.59492729  -60.55542994  123.03443642
#   142.75185147  112.17165347  -76.78894551   33.38526669   95.31429941
#   -31.93627941  -18.85038051  107.09042691  100.27337761   57.34581621
#    13.10121843  -31.47212784   61.44522082  -56.33698503   16.62143834
#    16.20509407   89.14922718  120.07183557  -72.30465139   71.08726625
#    38.75488054   93.27545396   10.75307527  106.9705666   -40.99523758
#    66.49315618  -55.25220177  116.55983601    6.22635996  -48.72810755
#   -36.55002051  132.27269035 -146.61671199   67.97537027   78.89187795
#  -116.81778468   83.70412097  -37.43907528  -14.97845907   14.19006546
#   104.61231      42.81334542 -132.0035914     6.72590628   33.08951849
#    23.67788118   76.31035333   39.44039166  -21.40416357   78.64306487
#   -34.01694915    4.93909559   59.99114695   46.45615398   18.54463558
#    72.48899231   53.33523047  -28.16023555  -37.37468714 -156.16882191
#    66.90361586  -12.21705801  -49.1421763    32.78222231  161.95668658
#   133.42443588   42.75286004  -21.44989111  -59.16254351   51.20323163
#  -120.07272903    8.04877755 -109.25380616   56.09338941   65.2327841
#    88.43706719  125.52340372  -52.84260199   77.26066437  -83.47822308
#   -16.88172325  104.39063678    1.97479412  -72.21333692   16.25549958
#   -55.84203676   79.82159636  123.94986924  -44.44302497   40.54298841
#   116.32768243  -15.18947382   -1.96023515  -27.00871147   53.07113195
#    -9.70380952  115.38888604    3.65725128   30.36618085   90.74431856
#   -19.35797386  -11.66615259   44.11401285  -14.23501908  137.6666306
#   -96.9643042  -102.6475733    85.13711843  -90.63248595   27.66926708
#    25.56154534  -76.8229026   100.06997297  -62.23000515   11.19758934
#    72.09499257   35.44108697    5.07523513   -2.92781675  154.05845645
#   -21.47185051   53.99637538  -89.8834833  -115.35406676   -4.88619887
#   -17.41979263   20.56902078  -84.06872006  -68.54578662   17.1935603
#   -77.72539383  -22.32179185  -77.95127368   16.93082666  -38.64001253
#    94.27485215  -82.98265726   87.56097924  -32.39942153  -79.73588654
#    74.57573727   38.92119139  -27.7275415  -103.74024285  -22.10206809
#   -28.74498368  107.93779093   -9.11186619  -83.33039529  -10.54238553
#   -14.5902515    65.33995011 -107.19173379   50.4895618     4.35321462
#   -98.99435107   -5.51264114  -39.12339118   80.78456099  -23.42585592
#   -99.91795833   83.15725583   29.65862134    5.79380068  -12.17246747
#   -33.3772854   162.38732622   89.73112255  115.70530796   90.00890855
#    37.6255217    41.23770222  -44.65460752  -86.60142942    4.16017441
#   -48.96575894  -63.70331659   11.18509652    0.78442436    2.10922283
#    11.15686941   28.97702759   28.79871616  -35.98384527    8.10883514
#    -4.23804948   16.13083432   21.48853468  -10.31417402  -50.31616501
#    13.77140632   -1.93500871  -72.6123045  -101.33678237  -35.6971874
#   -18.64313859   86.01384285  106.80740066  117.86927901  -16.30058316
#    78.36079054  -84.6756837   -19.79179682   40.950379    -73.19353914
#    31.0871448    -5.12381446   33.83071215 -102.96938804  -40.64883464
#   -76.34607558  -56.73057998   92.77907653   99.01941004   -4.93529229
#   -48.15753238  -37.89003071 -100.42368829   62.12506763   66.6855265
#   -69.04375374   35.40552371  -23.66567749    3.7776922    31.70350191
#    91.16414713   -4.63920308   37.01649995 -104.9431218    27.10727297
#   135.48934605  -69.77262102  -78.1268914   -68.06437902   99.86155473
#   -42.81368234]
#  % absolut error: [-1.29141993  1.35963056 -3.47813788 -3.27213831  1.52992167  1.12503429
#  -2.11512929  3.54751582 -2.92747738 -0.41721611  0.75518824 -0.76533146
#   1.28446771 -2.71868532 -1.23389747  2.73976999 -2.68187419  1.16465219
#  -4.55421456 -1.3124028  -0.63641868  0.38338279 -2.15597448 -2.33571989
#  -0.69506846 -2.51089451  3.01151008  1.97328963  1.21435185 -1.10345917
#  -2.6774021   4.70860015  4.80972266  4.66273292  4.14848458 -2.00924097
#  -2.63056292  0.02213618 -3.71225785  1.1798383  -2.14519232  0.65872125
#   0.02323416  3.22599748 -1.58471616  2.90399303 -0.12987912 -2.13511138
#  -1.01973245  2.81915721  2.49011299 -2.62816893 -0.32507048 -0.21567989
#  -0.99597855  3.99671457  3.39503373  1.62705862 10.22987555  1.94967009
#   3.4966586  -2.77140557  1.5033129  -0.84072933  1.22558623 -1.69288957
#  -3.25644552 -5.33494428  3.71781994  3.29169332 -2.51351972 -1.62416982
#   0.06341494  6.47939542 -1.4409556   6.10896311 -3.50542886 -1.91283826
#  -0.92890885 13.64662841  3.25918447 -3.13597451 -0.23564636  2.79263369
#   1.48031105 -2.50331161  0.1892445   0.04987417  1.4192624   3.30367287
#   2.14415244  1.50493537  2.16533485  5.06132184 -2.67905051  3.05401052
#   0.3120711  -0.92021296  0.32004545  2.96350584 -2.53779901 -4.31322079
#  -3.09038796  4.64431005  3.6775842   1.31074374  0.7460111   0.62764109
#  -2.49457643  0.53860954 -0.18821243  6.94623784  5.01297969  1.89318597
#  -2.38208593 -1.56214442 -0.01445783 -0.71960658 -2.21483417 -2.37107859
#  -1.38912398 -1.43279745 11.65135959 -1.46240874 -3.87819927  3.97073054
#  -1.95507158  3.74059645 -2.29652125 -2.69927596  1.82491858  5.34968218
#  -7.88836247 -3.64794872  0.7634847  -2.73802066 -2.76745584  2.64336068
#   1.91556682 -1.95250211  2.16591768 -1.42695243 -1.03110538  6.96243768
#  -1.55247987  0.43550116 -1.55834812 -0.86872661 -0.89917488 -4.78434794
#   0.82832261 -2.7794015  -2.34282723  7.45760731  3.9444996  -1.34194546
#  -3.97551345 -0.84890466  0.12902968  1.16249503 -2.15057481 -2.2157051
#  -2.3878832   1.03355163  2.45443517 -2.15451754  0.14014596 -2.21641094
#  -1.29471056 -2.97566706 -2.67615657 -1.50366614  1.48307708  1.37593832
#   3.42376125 -1.32911849 -0.43987708  3.44705191 -3.66100543 -3.1109649
#  -0.6969711  -0.76702576  2.47653911 -1.89029044  3.74964481  5.18551921
#  -2.98994055  0.35837005  0.3989915   0.73728535 -4.13573119 -3.17486479
#  -0.73733973  3.14302936  2.15839541  5.80205745 -4.01146792  2.87386826
#  -0.91358712  0.66353097  4.45770455  1.15822067 -3.0864667  -2.57575956
#  -4.67204774  1.03306799 -1.18544098  1.2373465  -7.28450906 -2.10064725
#   3.17467236  4.85062235  3.59318504 -3.64901467 -0.36231093  5.80865804
#   3.45074963 -0.20656357  4.79564602 -1.25283431  1.67454151 -0.88476578
#   0.90315488  2.60061662 -2.3309245  -0.74279039 -0.61573451  1.7606265
#   3.59290336 -3.19306922 -1.27032828 -2.52773772 -0.69311363  2.35737151
#   1.75605224 -3.23855211 -2.47995205  3.83612424  2.63252954 -5.81928719
#  -0.50139249 -2.30862903 -0.13102997 -0.87365299 -5.04317371 -2.2121196
#   1.42584434  5.06516111 -1.54905714 -0.51249462 -2.64696522 -2.34683856
#   4.73629216 -1.78478494  4.24115033 -1.23871544 -2.20640681  0.1225469
#   2.87703373  1.82577505 -3.41373978 -1.09444702 -3.43137492 -2.45219328
#   5.38243783  6.29936105  4.8840095  -3.08926172  1.40540026  4.11979357
#  -1.308424   -0.77645973  4.65247727  4.34345111  2.4386512   0.54684498
#  -1.28965303  2.61754296 -2.28527111  0.69479989  0.67727823  3.8430783
#   5.24603254 -2.91411331  3.04078034  1.63513788  4.02811825  0.44839399
#   4.64702803 -1.67335742  2.8386874  -2.24225429  5.08478833  0.25914469
#  -1.98274193 -1.49462299  5.81006888 -5.73729861  2.90380269  3.38592883
#  -4.62516126  3.59989859 -1.5304223  -0.61795827  0.59256278  4.53992931
#   1.80947022 -5.19517617  0.27999431  1.39277692  0.99269745  3.27150873
#   1.66454226 -0.8807253   3.37488972 -1.39248167  0.20545793  2.55401793
#   1.96645804  0.77581599  3.10259992  2.26423792 -1.15550773 -1.52783048
#  -6.0883275   2.85671109 -0.5046075  -1.99925351  1.37966401  7.20791808
#   5.86362565  1.80686766 -0.88259026 -2.39714042  2.17176262 -4.74791535
#   0.33524905 -4.33867448  2.38412152  2.78338266  3.8112082   5.49730949
#  -2.14656656  3.3135996  -3.34936147 -0.69593376  4.52987344  0.08204689
#  -2.91054016  0.6793992  -2.26564875  3.42719857  5.4246581  -1.81154094
#   1.71187285  5.07414701 -0.62660944 -0.08130907 -1.10878079  2.25277358
#  -0.40121798  5.03113701  0.15205432  1.27668498  3.9145318  -0.79720116
#  -0.48196284  1.86546731 -0.58746675  6.06135842 -3.86951998 -4.08705074
#   3.6637861  -3.6260006   1.16198114  1.07251725 -3.09058561  4.33425854
#  -2.51829753  0.46701641  3.08521606  1.49323523  0.21113306 -0.1213949
#   6.83238891 -0.88348584  2.29294905 -3.5971126  -4.56985671 -0.20243015
#  -0.71795593  0.86123565 -3.37225477 -2.76681037  0.71888733 -3.12575796
#  -0.91813663 -3.13455707  0.70782431 -1.5787388   4.07303534 -3.33014024
#   3.77202893 -1.32714703 -3.20402019  3.19476804  1.64227007 -1.1379549
#  -4.12876058 -0.90918116 -1.17921894  4.69101739 -0.37683546 -3.34362856
#  -0.43573903 -0.60203862  2.78808276 -4.26027438  2.1408446   0.18104216
#  -3.94733451 -0.22832375 -1.59817286  3.46997884 -0.96311146 -3.98269598
#   3.57553839  1.24656623  0.24109792 -0.50277502 -1.36665493  7.22846918
#   3.86913342  5.04562963  3.88157626  1.58673214  1.74171711 -1.82000828
#  -3.47032386  0.17300008 -1.9922193  -2.5763828   0.46649294  0.03257441
#   0.0876369   0.4653102   1.21756971  1.20998669 -1.47181141  0.33775903
#  -0.17562515  0.67415369  0.90008271 -0.42634679 -2.04603773  0.57497947
#  -0.08026354 -2.92614991 -4.03696677 -1.46025774 -0.76798886  3.70291208
#   4.63961089  5.14485015 -0.67213781  3.3623689  -3.39577517 -0.81492129
#   1.72937185 -2.94888195  1.30739275 -0.21225343  1.42441902 -4.09933895
#  -1.65945247 -3.07199215 -2.30086966  4.0058234   4.28680567 -0.20445988
#  -1.95998033 -1.54857085 -4.00204746  2.64727086  2.84713378 -2.78635046
#   1.49171449 -0.97287537  0.15706965  1.3336598   3.93335474 -0.19221704
#   1.56064783 -4.17463545  1.13811138  5.95978092 -2.81493685 -3.14139712
#  -2.7479126   4.32484106 -1.74628712] %

# %% [markdown]
# <html> <h3 style="font-style:italic; color:red;">
# Run the previous cell several times and look at the results
# </h3> </html>
#
#
# <html> <h3 style="color:blue;">Describe the results in the cell below </h3> </html>

# %% [markdown]
# <html> <h3 style="color:blue;"> Price chart </h3> </html>

# %% [markdown]
# #### Now just press 'CTRL' and 'ENTER' keys on the next cells.

# %%
fig = plt.figure(figsize=(17,6)) 
ax1 = fig.add_subplot(111)
line1 = ax1.plot(y_test * sp500_min_train_delta + sp500_min_train_min)
line2 = ax1.plot(pred[:,0] * sp500_min_train_delta + sp500_min_train_min)
plt.legend(labels=['Actual prices', 'Predicted prices'], loc='upper right')

plt.show();

# %% [markdown]
# <html> <h3 style="color:blue;"> Error Chart </h3> </html>

# %%
# Shows the absolute error in predicting the SP values ​​at each minute.

# %% [markdown]
# #### Now just press 'CTRL' and 'ENTER' keys on the next cells.

# %%
plt.ion()  # interactive mode, used for graphs of many functions 
# More details: https://www.geeksforgeeks.org/matplotlib-pyplot-ion-in-python/

fig = plt.figure(figsize=(17,6)) 
ax1 = fig.add_subplot(111)
a = (pred - y_test) * sp500_min_train_delta
line1 = ax1.plot(a)

plt.show()

# %%
# Further improvement of the predictive system should be aimed at reducing the outliers on the graph.

# %% [markdown]
# # Lab Logbook Requirement:

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;">
#
# 1) Create your own Multi-layer Perceptron (MLP) with two hidden layers, where the first hidden layer cells' number equals the last three digits of your SID. The number of cells in the next hidden layer is approximately two times smaller. For example, if your SID is 2287167, the number of cells on the first hidden layer is 167, and on the second - 84. Take epochs=10. Leave other parameters the same as in the practical session.
# 2) Compile the model.
# 3) Train your MLP with the same datasets and demonstrate the received MAE.
# 4) Compare your MAE with the MAE of the MLP in the practical session.
# 5) Please only add to your Lab Logbook a print-screen of your MLP architecture using model.summary() and the resulting MAE.
#
# </h3> </html>

# %% [markdown]
# <html> <h3 style="color:red;">
# NOTE: DON'T FORGET TO SAVE AND BACK UP YOUR COMPLETED JUPYTER NOTEBOOK AND LAB LOGBOOK ON GITHUB OR ONEDRIVE.
# </h3> </html>

# %%
#Student ID: 2368044

# %%
model_2 = keras.Sequential([
    keras.layers.Dense(44, input_shape=(500,), activation=tf.nn.relu, kernel_initializer="normal"),
    keras.layers.Dense(22, activation='relu', kernel_initializer="normal"),
    keras.layers.Dense(1)
])
print(model_2.summary())
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_5 (Dense)                      │ (None, 44)                  │          22,044 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 22)                  │             990 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 1)                   │              23 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 23,057 (90.07 KB)
#  Trainable params: 23,057 (90.07 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
model_2.compile(optimizer="adam",loss="mse", metrics=["mae"])

# %%
history_2=model_2.fit(X_train, y_train, batch_size=10, epochs=10, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/10
# 2640/2640 ━━━━━━━━━━━━━━━━━━━━ 4s 993us/step - loss: 0.0591 - mae: 0.2022 - val_loss: 0.0708 - val_mae: 0.2304
# Epoch 2/10
# 2640/2640 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0563 - mae: 0.1992 - val_loss: 0.0707 - val_mae: 0.2297
# Epoch 3/10
# 2640/2640 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0562 - mae: 0.1989 - val_loss: 0.0706 - val_mae: 0.2290
# Epoch 4/10
# 2640/2640 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0565 - mae: 0.1994 - val_loss: 0.0707 - val_mae: 0.2282
# Epoch 5/10
# 2640/2640 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0563 - mae: 0.1990 - val_loss: 0.0707 - val_mae: 0.2292
# Epoch 6/10
# 2640/2640 ━━━━━━━━━━━━━━━━━━━━ 3s 999us/step - loss: 0.0562 - mae: 0.1989 - val_loss: 0.0707 - val_mae: 0.2283
# Epoch 7/10
# 2640/2640 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0563 - mae: 0.1991 - val_loss: 0.0707 - val_mae: 0.2284
# Epoch 8/10
# 2640/2640 ━━━━━━━━━━━━━━━━━━━━ 3s 951us/step - loss: 0.0562 - mae: 0.1988 - val_loss: 0.0707 - val_mae: 0.2289
# Epoch 9/10
# 2640/2640 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0563 - mae: 0.1990 - val_loss: 0.0707 - val_mae: 0.2282
# Epoch 10/10
# 2640/2640 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0562 - mae: 0.1988 - val_loss: 0.0707 - val_mae: 0.2284

# %%
mse, mae = model_2.evaluate(X_test, y_test, verbose=0)
print("Mean absolute error:%.5f."%mae)
# Out:
# Mean absolute error:0.33471.

# %%
#Comparison: 
#Current Mean absolute error:0.33471 and Previous Mean absolute error:0.33341 is hence proved previous MAE is better than current MAE.
